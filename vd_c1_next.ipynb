# %%
print('Hello world')
# Out:
# Hello world

# %%
if (5>2): print('Five is greater than two')
# Out:
# Five is greater than two

# %%
total = 1+\
2+\
+3
print(total);print('Hello Python!')
# Out:
# 6
# Hello Python!

# %%
if True:
    print('True')
else:
    print('False')
# Out:
# True

# %%
#This is a comment
print('Hello, world!')
# Out:
# Hello, world!

# %%
import math
import os

# %%
def add(a,b):
  result = a+b
  return result
